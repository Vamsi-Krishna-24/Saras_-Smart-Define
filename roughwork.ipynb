# %%
text = "hello world"
print(text.upper())  # ----> upper() is a method of the string object
# Out:
# HELLO WORLD

# %%
#reading and understanding the data

with open ('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark2/SARAS/Saras_-Smart-Define/DataBase/dict/data.adj','r') as file:
    for index, line in enumerate(file):
        if index == 100:
            break
        print(line)
# Out:
#   1 This software and database is being provided to you, the LICENSEE, by
#
#   2 Princeton University under the following license.  By obtaining, using
#
#   3 and/or copying this software and database, you agree that you have
#
#   4 read, understood, and will comply with these terms and conditions.:
#
#   5
#
#   6 Permission to use, copy, modify and distribute this software and
#
#   7 database and its documentation for any purpose and without fee or
#
#   8 royalty is hereby granted, provided that you agree to comply with
#
#   9 the following copyright notice and statements, including the disclaimer,
#
#   10 and that the same appear on ALL copies of the software, database and
#
#   11 documentation, including modifications that you make for internal
#
#   12 use or for distribution.
#
#   13
#
#   14 WordNet 3.1 Copyright 2011 by Princeton University.  All rights reserved.
#
#   15
#
#   16 THIS SOFTWARE AND DATABASE IS PROVIDED "AS IS" AND PRINCETON
#
#   17 UNIVERSITY MAKES NO REPRESENTATIONS OR WARRANTIES, EXPRESS OR
#
#   18 IMPLIED.  BY WAY OF EXAMPLE, BUT NOT LIMITATION, PRINCETON
#
#   19 UNIVERSITY MAKES NO REPRESENTATIONS OR WARRANTIES OF MERCHANT-
#
#   20 ABILITY OR FITNESS FOR ANY PARTICULAR PURPOSE OR THAT THE USE
#
#   21 OF THE LICENSED SOFTWARE, DATABASE OR DOCUMENTATION WILL NOT
#
#   22 INFRINGE ANY THIRD PARTY PATENTS, COPYRIGHTS, TRADEMARKS OR
#
#   23 OTHER RIGHTS.
#
#   24
#
#   25 The name of Princeton University or Princeton may not be used in
#
#   26 advertising or publicity pertaining to distribution of the software
#
#   27 and/or database.  Title to copyright in this software, database and
#
#   28 any associated documentation shall at all times remain with
#
#   29 Princeton University and LICENSEE agrees to preserve same.
#
# 00001740 00 a 01 able 0 005 = 05207437 n 0000 = 05624029 n 0000 + 05624029 n 0101 + 05207437 n 0101 ! 00002098 a 0101 | (usually followed by `to') having the necessary means or skill or know-how or authority to do something; "able to swim"; "she was able to program her computer"; "we were at last able to buy a car"; "able to get a grant for the project"
#
# 00002098 00 a 01 unable 0 002 = 05207437 n 0000 ! 00001740 a 0101 | (usually followed by `to') not having the necessary means or skill or know-how; "unable to get to town without a car"; "unable to obtain funds"
#
# 00002312 00 a 02 abaxial 0 dorsal 4 002 ;c 06047178 n 0000 ! 00002527 a 0101 | facing away from the axis of an organ or organism; "the abaxial surface of a leaf is the underside or side facing away from the stem"
#
# 00002527 00 a 02 adaxial 0 ventral 4 002 ;c 06047178 n 0000 ! 00002312 a 0101 | nearest to or facing toward the axis of an organ or organism; "the upper side of a leaf is known as the adaxial surface"
#
# 00002730 00 a 01 acroscopic 0 002 ;c 06076105 n 0000 ! 00002843 a 0101 | facing or on the side toward the apex
#
# 00002843 00 a 01 basiscopic 0 002 ;c 06076105 n 0000 ! 00002730 a 0101 | facing or on the side toward the base
#
# 00002956 00 a 02 abducent 0 abducting 0 002 ;c 06090110 n 0000 ! 00003131 a 0101 | especially of muscles; drawing away from the midline of the body or from an adjacent part
#
# 00003131 00 a 03 adducent 0 adductive 0 adducting 0 003 ;c 06090110 n 0000 + 01451829 v 0201 ! 00002956 a 0101 | especially of muscles; bringing together or drawing toward the midline of the body or toward an adjacent part
#
# 00003356 00 a 01 nascent 0 005 + 07334902 n 0103 ! 00003938 a 0101 & 00003552 a 0000 & 00003699 a 0000 & 00003828 a 0000 | being born or beginning; "the nascent chicks"; "a nascent insurgency"
#
# 00003552 00 s 02 emergent 0 emerging 0 003 & 00003356 a 0000 + 02631097 v 0102 + 00051513 n 0101 | coming into existence; "an emergent republic"
#
# 00003699 00 s 01 dissilient 0 002 & 00003356 a 0000 + 07449382 n 0101 | bursting open with force, as do some ripe seed vessels
#
# 00003828 00 s 01 parturient 0 002 & 00003356 a 0000 + 14071923 n 0101 | giving birth; "a parturient heifer"
#
# 00003938 00 a 01 dying 0 003 ! 00003356 a 0101 & 00004170 a 0000 & 00004295 a 0000 | in or associated with the process of passing from life or ceasing to be; "a dying man"; "his dying wish"; "a dying fire"; "a dying civilization"
#
# 00004170 00 s 01 moribund 0 001 & 00003938 a 0000 | being on the point of death; breathing your last; "a moribund patient"
#
# 00004295 00 s 01 last 0 001 & 00003938 a 0000 | occurring at the time of death; "his last words"; "the last rites"
#
# 00004412 00 a 01 abridged 0 005 ^ 01445077 a 0000 ! 00004979 a 0101 & 00004614 a 0000 & 00004722 a 0000 & 00004816 a 0000 | (used of texts) shortened by condensing or rewriting; "an abridged version"
#
# 00004614 00 s 02 cut 0 shortened 0 001 & 00004412 a 0000 | with parts removed; "the drastically cut film"
#
# 00004722 00 s 01 half-length 0 001 & 00004412 a 0000 | abridged to half its original length
#
# 00004816 00 s 01 potted 0 003 & 00004412 a 0000 ;r 08879115 n 0000 ;u 07089193 n 0000 | (British informal) summarized or abridged; "a potted version of a novel"
#
# 00004979 00 a 01 unabridged 0 002 ! 00004412 a 0101 & 00005106 a 0000 | (used of texts) not shortened; "an unabridged novel"
#
# 00005106 00 s 02 full-length 0 uncut 0 001 & 00004979 a 0000 | complete; "the full-length play"
#
# 00005204 00 a 01 absolute 0 007 + 05863039 n 0101 + 04745638 n 0101 ! 00006050 a 0101 & 00005472 a 0000 & 00005598 a 0000 & 00005717 a 0000 & 00005838 a 0000 | perfect or complete or pure; "absolute loyalty"; "absolute silence"; "absolute truth"; "absolute alcohol"
#
# 00005472 00 s 01 direct 0 001 & 00005204 a 0000 | lacking compromising or mitigating elements; exact; "the direct opposite"
#
# 00005598 00 s 02 implicit 0 unquestioning 0 001 & 00005204 a 0000 | being without doubt or reserve; "implicit trust"
#
# 00005717 00 s 01 infinite 0 002 & 00005204 a 0000 + 05216592 n 0101 | total and all-embracing; "God's infinite wisdom"
#
# 00005838 00 s 01 living 0 003 & 00005204 a 0000 ;u 06332047 n 0000 ;u 07089193 n 0000 | (informal) absolute; "she is a living doll"; "scared the living daylights out of them"; "beat the living hell out of him"
#
# 00006050 00 a 02 relative 0 comparative 0 005 + 00655291 v 0201 + 00654571 v 0201 + 05219877 n 0101 ! 00005204 a 0101 & 00006263 a 0000 | estimated by comparison; not absolute or complete; "a relative stranger"
#
# 00006263 00 s 01 relational 0 001 & 00006050 a 0000 | having a relation or being related
#
# 00006354 00 a 02 absorbent 0 absorptive 0 015 = 04948141 n 0000 + 02771422 v 0201 + 01542421 v 0201 + 05017246 n 0201 + 04948141 n 0101 + 02771422 v 0101 + 01542421 v 0101 ! 00007832 a 0101 & 00006795 a 0000 & 00006903 a 0000 & 00007115 a 0000 & 00007227 a 0000 & 00007350 a 0000 & 00007535 a 0000 & 00007716 a 0000 | having power or capacity or tendency to absorb or soak up something (liquids or energy etc.); "as absorbent as a sponge"
#
# 00006795 00 s 02 absorbefacient 0 sorbefacient 0 001 & 00006354 a 0000 | inducing or promoting absorption
#
# 00006903 00 s 03 assimilating 0 assimilative 0 assimilatory 0 003 & 00006354 a 0000 + 01542830 v 0301 + 01542830 v 0201 | capable of taking (gas, light, or liquids) into a solution; "an assimilative substance"
#
# 00007115 00 s 01 hygroscopic 0 002 & 00006354 a 0000 + 03559825 n 0101 | absorbing moisture (as from the air)
#
# 00007227 00 s 01 receptive 0 001 & 00006354 a 0000 | able to absorb liquid (not repellent); "the paper is ink-receptive"
#
# 00007350 00 s 01 shock-absorbent 0 001 & 00006354 a 0000 | having the capacity to absorb the energy of an impact; "the material absorbs shock and is used for shock-absorbent insoles"
#
# 00007535 00 s 02 spongy 0 spongelike 0 003 & 00006354 a 0000 + 14621938 n 0101 + 04947556 n 0101 | like a sponge in being able to absorb liquids and yield it back when compressed
#
# 00007716 00 s 01 thirsty 0 001 & 00006354 a 0000 | able to take in large quantities of moisture; "thirsty towels"
#
# 00007832 00 a 02 nonabsorbent 0 nonabsorptive 0 004 = 04948141 n 0000 + 04949915 n 0101 ! 00006354 a 0101 & 00008009 a 0000 | not capable of absorbing or soaking up (liquids)
#
# 00008009 00 s 02 repellent 0 resistant 0 003 & 00007832 a 0000 + 01118334 v 0201 + 05203322 n 0101 | incapable of absorbing or mixing with; "a water-repellent fabric"; "plastic highly resistant to steam and water"
#
# 00008225 00 a 03 adsorbent 0 adsorptive 0 surface-assimilative 0 005 + 01543020 v 0201 + 14622705 n 0101 + 01543020 v 0101 ! 00008614 a 0101 & 00008462 a 0000 | having capacity or tendency to adsorb or cause to accumulate on a surface
#
# 00008462 00 s 02 chemisorptive 0 chemosorptive 0 001 & 00008225 a 0000 | having the capacity to adsorb by chemical as contrasted with physical forces
#
# 00008614 00 a 02 nonadsorbent 0 nonadsorptive 0 001 ! 00008225 a 0101 | lacking a capacity to adsorb or cause to accumulate on a surface
#
# 00008753 00 a 01 absorbable 0 002 + 02771422 v 0101 ! 00008896 a 0101 | capable of being absorbed or taken in through the pores of a surface
#
# 00008896 00 a 02 adsorbable 0 adsorbate 0 003 + 14622884 n 0201 + 01543020 v 0101 ! 00008753 a 0101 | capable of being adsorbed or accumulated on a surface of a solid
#
# 00009065 00 a 01 abstemious 0 006 ^ 01302836 a 0000 = 04891137 n 0000 + 04891137 n 0101 ! 00009997 a 0101 & 00009365 a 0000 & 00009637 a 0000 | sparing in consumption of especially food and drink; "the pleasures of the table, never of much consequence to one naturally abstemious"- John Galsworthy
#
# 00009365 00 s 02 abstinent 0 abstentious 0 006 & 00009065 a 0000 + 04889817 n 0202 + 09777275 n 0102 + 04889817 n 0101 + 01070697 n 0101 + 01198570 v 0101 | self-restraining; not indulging an appetite especially for food or drink; "not totally abstinent but abstemious"
#
# 00009637 00 s 04 ascetic 0 ascetical 0 austere 0 spartan 0 004 & 00009065 a 0000 + 04889193 n 0301 + 09777504 n 0202 + 09777504 n 0102 | practicing great self-denial; "Be systematically ascetic...do...something for no other reason than that you would rather not do it"- William James; "a desert nomad's austere life"; "a spartan diet"; "a spartan existence"
#
# 00009997 00 a 01 gluttonous 0 010 ^ 01300436 a 0000 = 04893296 n 0000 + 10152508 n 0101 ! 00009065 a 0101 & 00010404 a 0000 & 00010556 a 0000 & 00010745 a 0000 & 00011179 a 0000 & 00011346 a 0000 & 00011684 a 0000 | given to excess in consumption of especially food or drink; "over-fed women and their gluttonous husbands"; "a gluttonous debauch"; "a gluttonous appetite for food and praise and pleasure"
#
# 00010404 00 s 01 crapulous 1 002 & 00009997 a 0000 + 00749813 n 0105 | given to gross intemperance in eating or drinking; "a crapulous old reprobate"
#
# 00010556 00 s 02 crapulent 0 crapulous 2 003 & 00009997 a 0000 + 00749813 n 0205 + 00749813 n 0105 | suffering from excessive eating or drinking; "crapulent sleep"; "a crapulous stomach"
#
# 00010745 00 s 07 edacious 0 esurient 0 rapacious 0 ravening 0 ravenous 0 voracious 0 wolfish 0 011 & 00009997 a 0000 + 14063553 n 0605 + 04893597 n 0606 + 14063553 n 0604 + 04893597 n 0605 + 14063553 n 0503 + 04893597 n 0303 + 04893597 n 0304 + 04893597 n 0202 + 14063553 n 0101 + 04893597 n 0101 | devouring or craving food in great quantities; "edacious vultures"; "a rapacious appetite"; "ravenous as wolves"; "voracious sharks"
#
# 00011179 00 s 01 greedy 0 002 & 00009997 a 0000 + 04893430 n 0101 | wanting to eat or drink more than one can reasonably consume; "don't be greedy with the cookies"
#
# 00011346 00 s 05 hoggish 0 piggish 0 piggy 0 porcine 0 swinish 0 005 & 00009997 a 0000 + 02398346 n 0302 + 10199280 n 0302 + 04893430 n 0203 + 04893430 n 0102 | resembling swine; coarsely gluttonous or greedy; "piggish table manners"; "the piggy fat-cheeked little boy and his porcine pot-bellied father"; "swinish slavering over food"
#
# 00011684 00 s 02 overgreedy 0 too-greedy 0 001 & 00009997 a 0000 | excessively gluttonous
#
# 00011776 00 a 01 abstract 0 010 ^ 02400435 a 0000 ^ 01987315 a 0000 = 04769389 n 0000 + 05862715 n 0102 + 04769389 n 0101 ! 00013179 a 0101 & 00012090 a 0000 & 00012381 a 0000 & 00012708 a 0000 & 00012951 a 0000 | existing only in the mind; separated from embodiment; "abstract words like `truth' and `justice'"
#
# 00012090 00 s 03 conceptional 0 ideational 0 notional 0 004 & 00011776 a 0000 + 05844922 n 0301 + 05792704 n 0201 + 05844071 n 0102 | being of the nature of a notion or concept; "a plan abstract and conceptional"; "to improve notional comprehension"; "a notional response to the question"
#
# 00012381 00 s 01 conceptual 0 004 & 00011776 a 0000 + 01636885 v 0103 + 05844071 n 0101 + 05844599 n 0103 | being or characterized by concepts or their formation; "conceptual discussions"; "the schizophrenic loses ability to abstract or do conceptual thinking"; "sex is a notional category, gender is a grammatical category"
#
# 00012708 00 s 01 ideal 0 003 & 00011776 a 0000 + 05842164 n 0101 + 04862755 n 0101 | constituting or existing only in the form of an idea or mental image or conception; "a poem or essay may be typical of its period in idea or ideal content"
#
# 00012951 00 s 02 ideological 0 ideologic 0 003 & 00011776 a 0000 + 05787565 n 0201 + 05787565 n 0101 | concerned with or suggestive of ideas; "ideological application of a theory"; "the drama's symbolism was very ideological"
#
# 00013179 00 a 01 concrete 0 008 ^ 02400023 a 0000 ^ 01840022 a 0000 ^ 01939402 a 0000 = 04767104 n 0000 + 04767104 n 0101 ! 00011776 a 0101 & 00013461 a 0000 & 00013681 a 0000 | capable of being perceived by the senses; not abstract or imaginary; "concrete objects such as trees"
#
# 00013461 00 s 01 objective 0 001 & 00013179 a 0000 | belonging to immediate experience of actual things or events; "objective benefits"; "an objective example"; "there is no objective evidence of anything of the kind"
#
# 00013681 00 s 02 real 0 tangible 0 003 & 00013179 a 0000 + 04767279 n 0202 + 13979383 n 0101 | capable of being treated as fact; "tangible evidence"; "his brief time as Prime Minister brought few real benefits to the poor"
#
# 00013906 00 a 01 abundant 0 021 ^ 00106545 a 0000 ^ 02029118 a 0000 = 05116040 n 0000 + 02721154 v 0101 + 05122340 n 0101 ! 00016794 a 0101 & 00014377 a 0000 & 00014509 a 0000 & 00014877 a 0000 & 00015134 a 0000 & 00015284 a 0000 & 00015517 a 0000 & 00015626 a 0000 & 00015758 a 0000 & 00015892 a 0000 & 00016043 a 0000 & 00016173 a 0000 & 00016285 a 0000 & 00016388 a 0000 & 00016570 a 0000 & 00016685 a 0000 | present in great quantity; "an abundant supply of water"
#
# 00014377 00 s 02 abounding 0 galore(ip) 0 001 & 00013906 a 0000 | existing in abundance; "abounding confidence"; "whiskey galore"
#
# 00014509 00 s 05 ample 0 copious 1 plenteous 0 plentiful 1 rich 0 008 & 00013906 a 0000 + 05123104 n 0503 + 05122868 n 0402 + 13796604 n 0312 + 05122868 n 0301 + 05122868 n 0303 + 05122340 n 0202 + 05120210 n 0101 | affording an abundant supply; "had ample food for the party"; "copious provisions"; "food is plentiful"; "a plenteous grape harvest"; "a rich supply"
#
# 00014877 00 s 02 copious 2 voluminous 0 005 & 00013906 a 0000 + 05113324 n 0203 + 05113324 n 0202 + 05122340 n 0102 + 00520033 r 0201 | large in number or quantity (especially of discourse); "she took copious notes"; "a subject of voluminous legislation"
#
# 00015134 00 s 01 easy 0 002 & 00013906 a 0000 ;c 06158935 n 0000 | obtained with little effort or sacrifice, often obtained illegally; "easy money"
#
# 00015284 00 s 05 exuberant 0 lush 0 luxuriant 0 profuse 0 riotous 0 005 & 00013906 a 0000 + 05123104 n 0402 + 00311594 v 0301 + 05123543 n 0301 + 05123543 n 0202 | produced or growing in extreme abundance; "their riotous blooming"
#
# 00015517 00 s 01 thick 0 001 & 00013906 a 0000 | abounding; having a lot of; "the top was thick with dust"
#
# 00015626 00 s 01 long 0 001 & 00013906 a 0000 | having or being more than normal or necessary; "long on brains"; "in long supply"
#
# 00015758 00 s 03 overabundant 0 plethoric 0 rife 0 003 & 00013906 a 0000 + 05127416 n 0202 + 05126667 n 0101 | excessively abundant
#
# 00015892 00 s 01 plentiful 2 002 & 00013906 a 0000 + 05122868 n 0102 | existing in great number or quantity; "rhinoceroses were once plentiful here"
