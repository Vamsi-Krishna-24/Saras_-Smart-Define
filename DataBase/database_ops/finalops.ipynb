# %%
import sqlite3

connection = sqlite3.connect("/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark2/SARAS/Saras_-Smart-Define/Backend/dictionary3.db")
cursor = connection.cursor()

cursor.execute("DROP TABLE IF EXISTS dictionary;")
cursor.execute("DROP TABLE IF EXISTS words;")

connection.commit()
connection.close()
