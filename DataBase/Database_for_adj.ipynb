# %%
with open ("/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark2/SARAS/Saras_-Smart-Define/DataBase/dict/data.adv","r") as file:
    for line in file:
        line = line.strip().split('|')

        if len(line)<2:
            continue

        words = line[0].split()
        
        d=[]
        for word in words:
            if word.isalpha() and len(word)>1:
                d.append(word)
                word1=d[0]
                synonm=d[1:]

        part2= line[1].split(';')

        for sentence in part2:
            defenition = part2[0]
            examples = part2[1:]

            print({

                "word1": word1,
                "synonm":synonm,
                "definition":defenition,
                "examples":examples
            })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 25
#      20 defenition = part2[0]
#      21 examples = part2[1:]
#      23 print({
#      24
# ---> 25     "word1": word1,
#      26     "synonm":synonm,
#      27     "definition":defenition,
#      28     "examples":examples
#      29 })
#
# NameError: name 'word1' is not defined

# %%
with open("/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark2/SARAS/Saras_-Smart-Define/DataBase/dict/data.adv", "r") as file:
    print(sum(1 for _ in file))
# Out:
# 3654

# %%
count = 0
with open("/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark2/SARAS/Saras_-Smart-Define/DataBase/dict/data.adj", "r") as file:
    for line in file:
        parts = line.strip().split('|')
        if len(parts) > 1 and parts[0].isalpha() and len(parts[0])>1
            count += 1

print(count)
# Out:
# 18185

# %%
with open ('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark2/SARAS/Saras_-Smart-Define/DataBase/dict/data.adv','r')as file:
    for line in file:
        line = line.split('|')

        if len(line)<2:
            continue

        words = line[0].split()

        d=[]
        for word in words:
            if len(word)>1 and word.isalpha():
                d.append(word)


                word1 = d[0]
                synonm= d[1:]

        part2 = line[1].split(';')

        for sentence in part2:
                definition=part2[0]
                sentence = part2[1:]
                



                print({

                    "word1":word,
                    "synonm":synonm,
                    "definition":definition,
                    "sentence":sentence
                })
# Out:
# {'word1': '0101', 'synonm': ['02', '02', 'a_cappella', 'a_capella', '002', '02260096', '0202', '02260096', '0101'], 'definition': ' without musical accompaniment', 'sentence': [' "they performed a cappella"  \n']}
# {'word1': '0101', 'synonm': ['02', '02', 'a_cappella', 'a_capella', '002', '02260096', '0202', '02260096', '0101'], 'definition': ' without musical accompaniment', 'sentence': [' "they performed a cappella"  \n']}
# {'word1': '000', 'synonm': ['02', '03', 'AD', 'A.D.', 'anno_Domini', '000'], 'definition': ' in the Christian era', 'sentence': [' used before dates after the supposed year Christ was born', ' "in AD 200"  \n']}
# {'word1': '000', 'synonm': ['02', '03', 'AD', 'A.D.', 'anno_Domini', '000'], 'definition': ' in the Christian era', 'sentence': [' used before dates after the supposed year Christ was born', ' "in AD 200"  \n']}
# ...
