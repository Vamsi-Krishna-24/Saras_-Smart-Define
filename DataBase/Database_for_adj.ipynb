# %%
with open("/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark2/SARAS/Saras_-Smart-Define/DataBase/dict/data.adv", "r") as file:
    print(sum(1 for _ in file))
# Out:
# 3654

# %%
count = 0
with open("/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark2/SARAS/Saras_-Smart-Define/DataBase/dict/data.adj", "r") as file:
    for line in file:
        parts = line.strip().split('|')
        if len(parts) > 1 and parts[0].isalpha() and len(parts[0])>1
            count += 1

print(count)
# Out:
#   Cell In[25], line 5
#     if len(parts) > 1 and parts[0].isalpha() and len(parts[0])>1
#                                                                 ^
# SyntaxError: expected ':'

# %%
parsed_files_1=[]

with open ('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark2/SARAS/Saras_-Smart-Define/DataBase/dict/data.adv','r')as file:
    for line in file:
        line = line.split('|')

        if len(line)<2:
            continue

        words = line[0].split()

        d=[]
        for word in words:
            if len(word)>1 and word.isalpha():
                d.append(word)


                word1 = d[0]
                synonm= d[1:]

        part2 = line[1].split(';')

        for sentence in part2:
                definition=part2[0]
                examples = part2[1:]
                



                parsed_files_1.append({

                    "word1":word1,
                    "synonm":synonm,
                    "definition":definition,
                    "examples":examples
                })

            
print(parsed_files_1)
# Out:
# [{'word1': 'voluminously', 'synonm': [], 'definition': ' without musical accompaniment', 'examples': [' "they performed a cappella"  \n']}, {'word1': 'voluminously', 'synonm': [], 'definition': ' without musical accompaniment', 'examples': [' "they performed a cappella"  \n']}, {'word1': 'AD', 'synonm': [], 'definition': ' in the Christian era', 'examples': [' used before dates after the supposed year Christ was born', ' "in AD 200"  \n']}, {'word1': 'AD', 'synonm': [], 'definition': ' in the Christian era', 'examples': [' used before dates after the supposed year Christ was born', ' "in AD 200"  \n']}, {'word1': 'AD', 'synonm': [], 'definition': ' in the Christian era', 'examples': [' used before dates after the supposed year Christ was born', ' "in AD 200"  \n']}, {'word1': 'CE', 'synonm': [], 'definition': ' of the period coinciding with the Christian era', 'examples': [' preferred by some writers who are not Christians', ' "in 200 CE"  \n']}, {'word1': 'CE', 'synonm': [], 'definition': ' of the period coinciding with the Christian era', 'examples': [' preferred by some writers who are not Christians', ' "in 200 CE"  \n']}, {'word1': 'CE', 'synonm': [], 'definition': ' of the period coinciding with the Christian era', 'examples': [' preferred by some writers who are not Christians', ' "in 200 CE"  \n']}, {'word1': 'BC', 'synonm': [], 'definition': ' before the Christian era', 'examples': [' used following dates before the supposed year Christ was born', ' "in 200 BC"  \n']}, {'word1': 'BC', 'synonm': [], 'definition': ' before the Christian era', 'examples': [' used following dates before the supposed year Christ was born', ' "in 200 BC"  \n']}, {'word1': 'BC', 'synonm': [], 'definition': ' before the Christian era', 'examples': [' used following dates before the supposed year Christ was born', ' "in 200 BC"  \n']}, {'word1': 'BCE', 'synonm': [], 'definition': ' of the period before the Common Era', 'examples': [' preferred by some writers who are not Christians', ' "in 200 BCE"  \n']}, {'word1': 'BCE', 'synonm': [], 'definition': ' of the period before the Common Era', 'examples': [' preferred by some writers who are not Christians', ' "in 200 BCE"  \n']}, {'word1': 'BCE', 'synonm': [], 'definition': ' of the period before the Common Era', 'examples': [' preferred by some writers who are not Christians', ' "in 200 BCE"  \n']}, {'word1': 'horseback', 'synonm': ['ahorse', 'ahorseback'], 'definition': ' on the back of a horse', 'examples': [' "he rode horseback to town"', ' "managed to escape ahorse"', ' "policeman patrolled the streets ahorseback"  \n']}, {'word1': 'horseback', 'synonm': ['ahorse', 'ahorseback'], 'definition': ' on the back of a horse', 'examples': [' "he rode horseback to town"', ' "managed to escape ahorse"', ' "policeman patrolled the streets ahorseback"  \n']}, {'word1': 'horseback', 'synonm': ['ahorse', 'ahorseback'], 'definition': ' on the back of a horse', 'examples': [' "he rode horseback to town"', ' "managed to escape ahorse"', ' "policeman patrolled the streets ahorseback"  \n']}, {'word1': 'horseback', 'synonm': ['ahorse', 'ahorseback'], 'definition': ' on the back of a horse', 'examples': [' "he rode horseback to town"', ' "managed to escape ahorse"', ' "policeman patrolled the streets ahorseback"  \n']}, {'word1': 'barely', 'synonm': ['hardly', 'just', 'scarcely', 'scarce'], 'definition': ' only a very short time before', 'examples': [' "we hardly knew them"', ' "had scarcely rung the bell when the door flew open"', ' "would have scarce arrived before she would have found some excuse to leave"- W.B.Yeats  \n']}, {'word1': 'barely', 'synonm': ['hardly', 'just', 'scarcely', 'scarce'], 'definition': ' only a very short time before', 'examples': [' "we hardly knew them"', ' "had scarcely rung the bell when the door flew open"', ' "would have scarce arrived before she would have found some excuse to leave"- W.B.Yeats  \n']}, {'word1': 'barely', 'synonm': ['hardly', 'just', 'scarcely', 'scarce'], 'de ...

# %%
parsed_files_1
# Out:
# [{'word1': 'voluminously',
#   'synonm': [],
#   'definition': ' without musical accompaniment',
#   'examples': [' "they performed a cappella"  \n']},
#  {'word1': 'voluminously',
#   'synonm': [],
#   'definition': ' without musical accompaniment',
#   'examples': [' "they performed a cappella"  \n']},
#  {'word1': 'AD',
#   'synonm': [],
#   'definition': ' in the Christian era',
#   'examples': [' used before dates after the supposed year Christ was born',
#    ' "in AD 200"  \n']},
#  {'word1': 'AD',
#   'synonm': [],
#   'definition': ' in the Christian era',
#   'examples': [' used before dates after the supposed year Christ was born',
#    ' "in AD 200"  \n']},
#  {'word1': 'AD',
#   'synonm': [],
#   'definition': ' in the Christian era',
#   'examples': [' used before dates after the supposed year Christ was born',
#    ' "in AD 200"  \n']},
#  {'word1': 'CE',
#   'synonm': [],
#   'definition': ' of the period coinciding with the Christian era',
#   'examples': [' preferred by some writers who are not Christians',
#    ' "in 200 CE"  \n']},
#  {'word1': 'CE',
#   'synonm': [],
#   'definition': ' of the period coinciding with the Christian era',
#   'examples': [' preferred by some writers who are not Christians',
#    ' "in 200 CE"  \n']},
#  {'word1': 'CE',
#   'synonm': [],
#   'definition': ' of the period coinciding with the Christian era',
#   'examples': [' preferred by some writers who are not Christians',
#    ' "in 200 CE"  \n']},
#  {'word1': 'BC',
#   'synonm': [],
#   'definition': ' before the Christian era',
#   'examples': [' used following dates before the supposed year Christ was born',
#    ' "in 200 BC"  \n']},
#  {'word1': 'BC',
#   'synonm': [],
#   'definition': ' before the Christian era',
#   'examples': [' used following dates before the supposed year Christ was born',
#    ' "in 200 BC"  \n']},
#  {'word1': 'BC',
#   'synonm': [],
#   'definition': ' before the Christian era',
#   'examples': [' used following dates before the supposed year Christ was born',
#    ' "in 200 BC"  \n']},
#  {'word1': 'BCE',
#   'synonm': [],
#   'definition': ' of the period before the Common Era',
#   'examples': [' preferred by some writers who are not Christians',
#    ' "in 200 BCE"  \n']},
#  {'word1': 'BCE',
#   'synonm': [],
#   'definition': ' of the period before the Common Era',
#   'examples': [' preferred by some writers who are not Christians',
#    ' "in 200 BCE"  \n']},
#  {'word1': 'BCE',
#   'synonm': [],
#   'definition': ' of the period before the Common Era',
#   'examples': [' preferred by some writers who are not Christians',
#    ' "in 200 BCE"  \n']},
#  {'word1': 'horseback',
#   'synonm': ['ahorse', 'ahorseback'],
#   'definition': ' on the back of a horse',
#   'examples': [' "he rode horseback to town"',
#    ' "managed to escape ahorse"',
#    ' "policeman patrolled the streets ahorseback"  \n']},
#  {'word1': 'horseback',
#   'synonm': ['ahorse', 'ahorseback'],
#   'definition': ' on the back of a horse',
#   'examples': [' "he rode horseback to town"',
#    ' "managed to escape ahorse"',
#    ' "policeman patrolled the streets ahorseback"  \n']},
#  {'word1': 'horseback',
#   'synonm': ['ahorse', 'ahorseback'],
#   'definition': ' on the back of a horse',
#   'examples': [' "he rode horseback to town"',
#    ' "managed to escape ahorse"',
#    ' "policeman patrolled the streets ahorseback"  \n']},
#  {'word1': 'horseback',
#   'synonm': ['ahorse', 'ahorseback'],
#   'definition': ' on the back of a horse',
#   'examples': [' "he rode horseback to town"',
#    ' "managed to escape ahorse"',
#    ' "policeman patrolled the streets ahorseback"  \n']},
#  {'word1': 'barely',
#   'synonm': ['hardly', 'just', 'scarcely', 'scarce'],
#   'definition': ' only a very short time before',
#   'examples': [' "we hardly knew them"',
#    ' "had scarcely rung the bell when the door flew open"',
#    ' "would have scarce arrived before she would have found some excuse to leave"- W.B.Yeats  \n']},
#  {'word1': 'barely',
#   'synonm': ['hardly', 'just', 'scarcely', 'scarce'],
#   'definition': ' only a very short time before',
#   'examples': [' "we hardly knew them"',
#    ' "had scarcely rung the bell when the door flew open"',
#    ' "would have scarce arrived before she would have found some excuse to leave"- W.B.Yeats  \n']},
#  {'word1': 'barely',
#   'synonm': ['hardly', 'just', 'scarcely', 'scarce'],
#   'definition': ' only a very short time before',
#   'examples': [' "we hardly knew them"',
#    ' "had scarcely rung the bell when the door flew open"',
#    ' "would have scarce arrived before she would have found some excuse to leave"- W.B.Yeats  \n']},
#  {'word1': 'barely',
#   'synonm': ['hardly', 'just', 'scarcely', 'scarce'],
#   'definition': ' only a very short time before',
#   'examples': [' "we hardly knew them"',
#    ' "had scarcely rung the bell when the door flew open"',
#    ' "would have scarce arrived before she would have found some excuse to leave"- W.B.Yeats  \n']},
#  {'word1': 'barely',
#   'synonm': ['just'],
#   'definition': ' by a little',
#   'examples': [' "I only just caught the bus"',
#    ' "he finished the marathon in just under 3 hours"',
#    ' "it was barely 5 a.m."',
#    ' "the network has barely 5 percent of viewers"',
#    ' "the batter just missed being hit"  \n']},
#  {'word1': 'barely',
#   'synonm': ['just'],
#   'definition': ' by a little',
#   'examples': [' "I only just caught the bus"',
#    ' "he finished the marathon in just under 3 hours"',
#    ' "it was barely 5 a.m."',
#    ' "the network has barely 5 percent of viewers"',
#    ' "the batter just missed being hit"  \n']},
#  {'word1': 'barely',
#   'synonm': ['just'],
#   'definition': ' by a little',
#   'examples': [' "I only just caught the bus"',
#    ' "he finished the marathon in just under 3 hours"',
#    ' "it was barely 5 a.m."',
#    ' "the network has barely 5 percent of viewers"',
#    ' "the batter just missed being hit"  \n']},
#  {'word1': 'barely',
#   'synonm': ['just'],
#   'definition': ' by a little',
#   'examples': [' "I only just caught the bus"',
#    ' "he finished the marathon in just under 3 hours"',
#    ' "it was barely 5 a.m."',
#    ' "the network has barely 5 percent of viewers"',
#    ' "the batter just missed being hit"  \n']},
#  {'word1': 'barely',
#   'synonm': ['just'],
#   'definition': ' by a little',
#   'examples': [' "I only just caught the bus"',
#    ' "he finished the marathon in just under 3 hours"',
#    ' "it was barely 5 a.m."',
#    ' "the network has barely 5 percent of viewers"',
#    ' "the batter just missed being hit"  \n']},
#  {'word1': 'barely',
#   'synonm': ['just'],
#   'definition': ' by a little',
#   'examples': [' "I only just caught the bus"',
#    ' "he finished the marathon in just under 3 hours"',
#    ' "it was barely 5 a.m."',
#    ' "the network has barely 5 percent of viewers"',
#    ' "the batter just missed being hit"  \n']},
#  {'word1': 'just',
#   'synonm': [],
#   'definition': ' exactly at this moment or the moment described',
#   'examples': [' "we\'ve just finished painting the walls, so don\'t touch them"  \n']},
#  {'word1': 'just',
#   'synonm': [],
#   'definition': ' exactly at this moment or the moment described',
#   'examples': [' "we\'ve just finished painting the walls, so don\'t touch them"  \n']},
#  {'word1': 'hardly',
#   'synonm': ['scarcely', 'barely', 'scarce'],
#   'definition': ' almost not',
#   'examples': [' "he hardly ever goes fishing"',
#    ' "he was scarce sixteen years old"',
#    ' "they scarcely ever used the emergency generator"',
#    ' "I can hardly hear what she is saying"',
#    ' "she barely seemed to notice him"',
#    ' "we were so far back in the theater, we could barely read the subtitles"  \n']},
#  {'word1': 'hardly',
#   'synonm': ['scarcely', 'barely', 'scarce'],
#   'definition': ' almost not',
#   'examples': [' "he hardly ever goes fishing"',
#    ' "he was scarce sixteen years old"',
#    ' "they scarcely ever used the emergency generator"',
#    ' "I can hardly hear what she is saying"',
#    ' "she barely seemed to notice him"',
#    ' "we were so far back in the theater, we could barely read the subtitles"  \n']},
#  {'word1': 'hardly',
#   'synonm': ['scarcely', 'barely', 'scarce'],
#   'definition': ' almost not',
#   'examples': [' "he hardly ever goes fishing"',
#    ' "he was scarce sixteen years old"',
#    ' "they scarcely ever used the emergency generator"',
#    ' "I can hardly hear what she is saying"',
#    ' "she barely seemed to notice him"',
#    ' "we were so far back in the theater, we could barely read the subtitles"  \n']},
#  {'word1': 'hardly',
#   'synonm': ['scarcely', 'barely', 'scarce'],
#   'definition': ' almost not',
#   'examples': [' "he hardly ever goes fishing"',
#    ' "he was scarce sixteen years old"',
#    ' "they scarcely ever used the emergency generator"',
#    ' "I can hardly hear what she is saying"',
#    ' "she barely seemed to notice him"',
#    ' "we were so far back in the theater, we could barely read the subtitles"  \n']},
#  {'word1': 'hardly',
#   'synonm': ['scarcely', 'barely', 'scarce'],
#   'definition': ' almost not',
#   'examples': [' "he hardly ever goes fishing"',
#    ' "he was scarce sixteen years old"',
#    ' "they scarcely ever used the emergency generator"',
#    ' "I can hardly hear what she is saying"',
#    ' "she barely seemed to notice him"',
#    ' "we were so far back in the theater, we could barely read the subtitles"  \n']},
#  {'word1': 'hardly',
#   'synonm': ['scarcely', 'barely', 'scarce'],
#   'definition': ' almost not',
#   'examples': [' "he hardly ever goes fishing"',
#    ' "he was scarce sixteen years old"',
#    ' "they scarcely ever used the emergency generator"',
#    ' "I can hardly hear what she is saying"',
#    ' "she barely seemed to notice him"',
#    ' "we were so far back in the theater, we could barely read the subtitles"  \n']},
#  {'word1': 'hardly',
#   'synonm': ['scarcely', 'barely', 'scarce'],
#   'definition': ' almost not',
#   'examples': [' "he hardly ever goes fishing"',
#    ' "he was scarce sixteen years old"',
#    ' "they scarcely ever used the emergency generator"',
#    ' "I can hardly hear what she is saying"',
#    ' "she barely seemed to notice him"',
#    ' "we were so far back in the theater, we could barely read the subtitles"  \n']},
#  {'word1': 'anisotropically',
#   'synonm': [],
#   'definition': ' in an anisotropic manner  \n',
#   'examples': []},
#  {'word1': 'annoyingly',
#   'synonm': [],
#   'definition': ' in an annoying manner or to an annoying degree  \n',
#   'examples': []},
#  {'word1': 'basically',
#   'synonm': ['fundamentally', 'essentially'],
#   'definition': ' in essence',
#   'examples': [" at bottom or by one's (or its) very nature",
#    ' "He is basically dishonest"',
#    ' "the argument was essentially a technical one"',
#    ' "for all his bluster he is in essence a shy person"  \n']},
#  {'word1': 'basically',
#   'synonm': ['fundamentally', 'essentially'],
#   'definition': ' in essence',
#   'examples': [" at bottom or by one's (or its) very nature",
#    ' "He is basically dishonest"',
#    ' "the argument was essentially a technical one"',
#    ' "for all his bluster he is in essence a shy person"  \n']},
#  {'word1': 'basically',
#   'synonm': ['fundamentally', 'essentially'],
#   'definition': ' in essence',
#   'examples': [" at bottom or by one's (or its) very nature",
#    ' "He is basically dishonest"',
#    ' "the argument was essentially a technical one"',
#    ' "for all his bluster he is in essence a shy person"  \n']},
#  {'word1': 'basically',
#   'synonm': ['fundamentally', 'essentially'],
#   'definition': ' in essence',
#   'examples': [" at bottom or by one's (or its) very nature",
#    ' "He is basically dishonest"',
#    ' "the argument was essentially a technical one"',
#    ' "for all his bluster he is in essence a shy person"  \n']},
#  {'word1': 'basically',
#   'synonm': ['fundamentally', 'essentially'],
#   'definition': ' in essence',
#   'examples': [" at bottom or by one's (or its) very nature",
#    ' "He is basically dishonest"',
#    ' "the argument was essentially a technical one"',
#    ' "for all his bluster he is in essence a shy person"  \n']},
#  {'word1': 'blessedly',
#   'synonm': [],
#   'definition': ' in a blessed manner  \n',
#   'examples': []},
#  {'word1': 'boiling',
#   'synonm': [],
#   'definition': ' extremely',
#   'examples': [' "boiling mad"  \n']},
#  {'word1': 'boiling',
#   'synonm': [],
#   'definition': ' extremely',
#   'examples': [' "boiling mad"  \n']},
#  {'word1': 'enviably',
#   'synonm': [],
#   'definition': ' in an enviable manner',
#   'examples': [' "she was enviably fluent in French"  \n']},
#  {'word1': 'enviably',
#   'synonm': [],
#   'definition': ' in an enviable manner',
#   'examples': [' "she was enviably fluent in French"  \n']},
#  {'word1': 'pointedly',
#   'synonm': [],
#   'definition': ' in such a manner as to make something clearly evident',
#   'examples': [' "he pointedly ignored the question"  \n']},
#  {'word1': 'pointedly',
#   'synonm': [],
#   'definition': ' in such a manner as to make something clearly evident',
#   'examples': [' "he pointedly ignored the question"  \n']},
#  {'word1': 'negatively',
#   'synonm': [],
#   'definition': ' in a negative way',
#   'examples': [' "he was negatively inclined"  \n']},
#  {'word1': 'negatively',
#   'synonm': [],
#   'definition': ' in a negative way',
#   'examples': [' "he was negatively inclined"  \n']},
#  {'word1': 'negatively',
#   'synonm': [],
#   'definition': ' in a harmful manner',
#   'examples': [' "he was negatively affected"  \n']},
#  {'word1': 'negatively',
#   'synonm': [],
#   'definition': ' in a harmful manner',
#   'examples': [' "he was negatively affected"  \n']},
#  {'word1': 'kindly',
#   'synonm': [],
#   'definition': ' in a kind manner or out of kindness',
#   'examples': [' "He spoke kindly to the boy"',
#    ' "she kindly overlooked the mistake"  \n']},
#  {'word1': 'kindly',
#   'synonm': [],
#   'definition': ' in a kind manner or out of kindness',
#   'examples': [' "He spoke kindly to the boy"',
#    ' "she kindly overlooked the mistake"  \n']},
#  {'word1': 'kindly',
#   'synonm': [],
#   'definition': ' in a kind manner or out of kindness',
#   'examples': [' "He spoke kindly to the boy"',
#    ' "she kindly overlooked the mistake"  \n']},
#  {'word1': 'unkindly',
#   'synonm': [],
#   'definition': ' in an unkind manner or with unkindness',
#   'examples': [' "The teacher treats the children unkindly"  \n']},
#  {'word1': 'unkindly',
#   'synonm': [],
#   'definition': ' in an unkind manner or with unkindness',
#   'examples': [' "The teacher treats the children unkindly"  \n']},
#  {'word1': 'merely',
#   'synonm': ['simply', 'just', 'only', 'but'],
#   'definition': ' and nothing more',
#   'examples': [' "I was merely asking"',
#    ' "it is simply a matter of time"',
#    ' "just a scratch"',
#    ' "he was only a child"',
#    ' "hopes that last but a moment"  \n']},
#  {'word1': 'merely',
#   'synonm': ['simply', 'just', 'only', 'but'],
#   'definition': ' and nothing more',
#   'examples': [' "I was merely asking"',
#    ' "it is simply a matter of time"',
#    ' "just a scratch"',
#    ' "he was only a child"',
#    ' "hopes that last but a moment"  \n']},
#  {'word1': 'merely',
#   'synonm': ['simply', 'just', 'only', 'but'],
#   'definition': ' and nothing more',
#   'examples': [' "I was merely asking"',
#    ' "it is simply a matter of time"',
#    ' "just a scratch"',
#    ' "he was only a child"',
#    ' "hopes that last but a moment"  \n']},
#  {'word1': 'merely',
#   'synonm': ['simply', 'just', 'only', 'but'],
#   'definition': ' and nothing more',
#   'examples': [' "I was merely asking"',
#    ' "it is simply a matter of time"',
#    ' "just a scratch"',
#    ' "he was only a child"',
#    ' "hopes that last but a moment"  \n']},
#  {'word1': 'merely',
#   'synonm': ['simply', 'just', 'only', 'but'],
#   'definition': ' and nothing more',
#   'examples': [' "I was merely asking"',
#    ' "it is simply a matter of time"',
#    ' "just a scratch"',
#    ' "he was only a child"',
#    ' "hopes that last but a moment"  \n']},
#  {'word1': 'merely',
#   'synonm': ['simply', 'just', 'only', 'but'],
#   'definition': ' and nothing more',
#   'examples': [' "I was merely asking"',
#    ' "it is simply a matter of time"',
#    ' "just a scratch"',
#    ' "he was only a child"',
#    ' "hopes that last but a moment"  \n']},
#  {'word1': 'simply',
#   'synonm': [],
#   'definition': ' absolutely',
#   'examples': [' altogether', ' really', ' "we are simply broke"  \n']},
#  {'word1': 'simply',
#   'synonm': [],
#   'definition': ' absolutely',
#   'examples': [' altogether', ' really', ' "we are simply broke"  \n']},
#  {'word1': 'simply',
#   'synonm': [],
#   'definition': ' absolutely',
#   'examples': [' altogether', ' really', ' "we are simply broke"  \n']},
#  {'word1': 'simply',
#   'synonm': [],
#   'definition': ' absolutely',
#   'examples': [' altogether', ' really', ' "we are simply broke"  \n']},
#  {'word1': 'plainly',
#   'synonm': ['simply'],
#   'definition': ' in a simple manner',
#   'examples': [' without extravagance or embellishment',
#    ' "she was dressed plainly"',
#    ' "they lived very simply"  \n']},
#  {'word1': 'plainly',
#   'synonm': ['simply'],
#   'definition': ' in a simple manner',
#   'examples': [' without extravagance or embellishment',
#    ' "she was dressed plainly"',
#    ' "they lived very simply"  \n']},
#  {'word1': 'plainly',
#   'synonm': ['simply'],
#   'definition': ' in a simple manner',
#   'examples': [' without extravagance or embellishment',
#    ' "she was dressed plainly"',
#    ' "they lived very simply"  \n']},
#  {'word1': 'plainly',
#   'synonm': ['simply'],
#   'definition': ' in a simple manner',
#   'examples': [' without extravagance or embellishment',
#    ' "she was dressed plainly"',
#    ' "they lived very simply"  \n']},
#  {'word1': 'anciently',
#   'synonm': [],
#   'definition': ' in ancient times',
#   'examples': [' long ago',
#    ' "a concern with what may have happened anciently"  \n']},
#  {'word1': 'anciently',
#   'synonm': [],
#   'definition': ' in ancient times',
#   'examples': [' long ago',
#    ' "a concern with what may have happened anciently"  \n']},
#  {'word1': 'anciently',
#   'synonm': [],
#   'definition': ' in ancient times',
#   'examples': [' long ago',
#    ' "a concern with what may have happened anciently"  \n']},
#  {'word1': 'arguably',
#   'synonm': [],
#   'definition': ' as can be shown by argument',
#   'examples': [' "she is arguably the best"  \n']},
#  {'word1': 'arguably',
#   'synonm': [],
#   'definition': ' as can be shown by argument',
#   'examples': [' "she is arguably the best"  \n']},
#  {'word1': 'unabashedly',
#   'synonm': [],
#   'definition': ' in an unabashed manner',
#   'examples': [' "unabashedly, he asked for more"  \n']},
#  {'word1': 'unabashedly',
#   'synonm': [],
#   'definition': ' in an unabashed manner',
#   'examples': [' "unabashedly, he asked for more"  \n']},
#  {'word1': 'automatically',
#   'synonm': [],
#   'definition': ' in a reflex manner',
#   'examples': [' "he answered automatically"  \n']},
#  {'word1': 'automatically',
#   'synonm': [],
#   'definition': ' in a reflex manner',
#   'examples': [' "he answered automatically"  \n']},
#  {'word1': 'alarmingly',
#   'synonm': [],
#   'definition': ' in an alarming manner',
#   'examples': [' "It grew alarmingly fast"  \n']},
#  {'word1': 'alarmingly',
#   'synonm': [],
#   'definition': ' in an alarming manner',
#   'examples': [' "It grew alarmingly fast"  \n']},
#  {'word1': 'vastly',
#   'synonm': ['immensely'],
#   'definition': ' to an exceedingly great extent or degree',
#   'examples': [' "He had vastly overestimated his resources"',
#    ' "was immensely more important to the project as a scientist than as an administrator"  \n']},
#  {'word1': 'vastly',
#   'synonm': ['immensely'],
#   'definition': ' to an exceedingly great extent or degree',
#   'examples': [' "He had vastly overestimated his resources"',
#    ' "was immensely more important to the project as a scientist than as an administrator"  \n']},
#  {'word1': 'vastly',
#   'synonm': ['immensely'],
#   'definition': ' to an exceedingly great extent or degree',
#   'examples': [' "He had vastly overestimated his resources"',
#    ' "was immensely more important to the project as a scientist than as an administrator"  \n']},
#  {'word1': 'grossly',
#   'synonm': [],
#   'definition': ' in a gross manner  \n',
#   'examples': []},
#  {'word1': 'largely',
#   'synonm': ['mostly'],
#   'definition': ' in large part',
#   'examples': [' mainly or chiefly',
#    ' "These accounts are largely inactive"  \n']},
#  {'word1': 'largely',
#   'synonm': ['mostly'],
#   'definition': ' in large part',
#   'examples': [' mainly or chiefly',
#    ' "These accounts are largely inactive"  \n']},
#  {'word1': 'largely',
#   'synonm': ['mostly'],
#   'definition': ' in large part',
#   'examples': [' mainly or chiefly',
#    ' "These accounts are largely inactive"  \n']},
#  {'word1': 'significantly',
#   'synonm': [],
#   'definition': ' in a significant manner',
#   'examples': [' "our budget will be significantly affected by these new cuts"  \n']},
#  {'word1': 'significantly',
#   'synonm': [],
#   'definition': ' in a significant manner',
#   'examples': [' "our budget will be significantly affected by these new cuts"  \n']},
#  {'word1': 'insignificantly',
#   'synonm': [],
#   'definition': ' not to a significant degree or amount',
#   'examples': [' "our budget will only be insignificantly affected by these new cuts"  \n']},
#  {'word1': 'insignificantly',
#   'synonm': [],
#   'definition': ' not to a significant degree or amount',
#   'examples': [' "our budget will only be insignificantly affected by these new cuts"  \n']},
#  {'word1': 'appreciably',
#   'synonm': [],
#   'definition': ' to a noticeable degree',
#   'examples': [' "they weather was appreciably colder"  \n']},
#  {'word1': 'appreciably',
#   'synonm': [],
#   'definition': ' to a noticeable degree',
#   'examples': [' "they weather was appreciably colder"  \n']},
#  {'word1': 'ultrasonically',
#   'synonm': [],
#   'definition': ' by ultrasonic means',
#   'examples': [' "the kidney stones were removed ultrasonically"  \n']},
#  {'word1': 'ultrasonically',
#   'synonm': [],
#   'definition': ' by ultrasonic means',
#   'examples': [' "the kidney stones were removed ultrasonically"  \n']},
#  {'word1': 'smartly',
#   'synonm': ['modishly', 'sprucely'],
#   'definition': ' in a stylish manner',
#   'examples': [' "He was smartly dressed"  \n']},
#  {'word1': 'smartly',
#   'synonm': ['modishly', 'sprucely'],
#   'definition': ' in a stylish manner',
#   'examples': [' "He was smartly dressed"  \n']},
#  {'word1': 'approximately',
#   'synonm': ['about', 'some', 'roughly', 'around'],
#   'definition': ' (of quantities) imprecise but fairly close to correct',
#   'examples': [' "lasted approximately an hour"',
#    ' "in just about a minute"',
#    ' "he\'s about 30 years old"',
#    ' "I\'ve had about all I can stand"',
#    ' "we meet about once a month"',
#    ' "some forty people came"',
#    ' "weighs around a hundred pounds"',
#    ' "roughly $3,000"',
#    ' "holds 3 gallons, more or less"',
#    ' "20 or so people were at the party"  \n']},
#  {'word1': 'approximately',
#   'synonm': ['about', 'some', 'roughly', 'around'],
#   'definition': ' (of quantities) imprecise but fairly close to correct',
#   'examples': [' "lasted approximately an hour"',
#    ' "in just about a minute"',
#    ' "he\'s about 30 years old"',
#    ' "I\'ve had about all I can stand"',
#    ' "we meet about once a month"',
#    ' "some forty people came"',
#    ' "weighs around a hundred pounds"',
#    ' "roughly $3,000"',
#    ' "holds 3 gallons, more or less"',
#    ' "20 or so people were at the party"  \n']},
#  {'word1': 'approximately',
#   'synonm': ['about', 'some', 'roughly', 'around'],
#   'definition': ' (of quantities) imprecise but fairly close to correct',
#   'examples': [' "lasted approximately an hour"',
#    ' "in just about a minute"',
#    ' "he\'s about 30 years old"',
#    ' "I\'ve had about all I can stand"',
#    ' "we meet about once a month"',
#    ' "some forty people came"',
#    ' "weighs around a hundred pounds"',
#    ' "roughly $3,000"',
#    ' "holds 3 gallons, more or less"',
#    ' "20 or so people were at the party"  \n']},
#  {'word1': 'approximately',
#   'synonm': ['about', 'some', 'roughly', 'around'],
#   'definition': ' (of quantities) imprecise but fairly close to correct',
#   'examples': [' "lasted approximately an hour"',
#    ' "in just about a minute"',
#    ' "he\'s about 30 years old"',
#    ' "I\'ve had about all I can stand"',
#    ' "we meet about once a month"',
#    ' "some forty people came"',
#    ' "weighs around a hundred pounds"',
#    ' "roughly $3,000"',
#    ' "holds 3 gallons, more or less"',
#    ' "20 or so people were at the party"  \n']},
#  {'word1': 'approximately',
#   'synonm': ['about', 'some', 'roughly', 'around'],
#   'definition': ' (of quantities) imprecise but fairly close to correct',
#   'examples': [' "lasted approximately an hour"',
#    ' "in just about a minute"',
#    ' "he\'s about 30 years old"',
#    ' "I\'ve had about all I can stand"',
#    ' "we meet about once a month"',
#    ' "some forty people came"',
#    ' "weighs around a hundred pounds"',
#    ' "roughly $3,000"',
#    ' "holds 3 gallons, more or less"',
#    ' "20 or so people were at the party"  \n']},
#  {'word1': 'approximately',
#   'synonm': ['about', 'some', 'roughly', 'around'],
#   'definition': ' (of quantities) imprecise but fairly close to correct',
#   'examples': [' "lasted approximately an hour"',
#    ' "in just about a minute"',
#    ' "he\'s about 30 years old"',
#    ' "I\'ve had about all I can stand"',
#    ' "we meet about once a month"',
#    ' "some forty people came"',
#    ' "weighs around a hundred pounds"',
#    ' "roughly $3,000"',
#    ' "holds 3 gallons, more or less"',
#    ' "20 or so people were at the party"  \n']},
#  {'word1': 'approximately',
#   'synonm': ['about', 'some', 'roughly', 'around'],
#   'definition': ' (of quantities) imprecise but fairly close to correct',
#   'examples': [' "lasted approximately an hour"',
#    ' "in just about a minute"',
#    ' "he\'s about 30 years old"',
#    ' "I\'ve had about all I can stand"',
#    ' "we meet about once a month"',
#    ' "some forty people came"',
#    ' "weighs around a hundred pounds"',
#    ' "roughly $3,000"',
#    ' "holds 3 gallons, more or less"',
#    ' "20 or so people were at the party"  \n']},
#  {'word1': 'approximately',
#   'synonm': ['about', 'some', 'roughly', 'around'],
#   'definition': ' (of quantities) imprecise but fairly close to correct',
#   'examples': [' "lasted approximately an hour"',
#    ' "in just about a minute"',
#    ' "he\'s about 30 years old"',
#    ' "I\'ve had about all I can stand"',
#    ' "we meet about once a month"',
#    ' "some forty people came"',
#    ' "weighs around a hundred pounds"',
#    ' "roughly $3,000"',
#    ' "holds 3 gallons, more or less"',
#    ' "20 or so people were at the party"  \n']},
#  {'word1': 'approximately',
#   'synonm': ['about', 'some', 'roughly', 'around'],
#   'definition': ' (of quantities) imprecise but fairly close to correct',
#   'examples': [' "lasted approximately an hour"',
#    ' "in just about a minute"',
#    ' "he\'s about 30 years old"',
#    ' "I\'ve had about all I can stand"',
#    ' "we meet about once a month"',
#    ' "some forty people came"',
#    ' "weighs around a hundred pounds"',
#    ' "roughly $3,000"',
#    ' "holds 3 gallons, more or less"',
#    ' "20 or so people were at the party"  \n']},
#  {'word1': 'approximately',
#   'synonm': ['about', 'some', 'roughly', 'around'],
#   'definition': ' (of quantities) imprecise but fairly close to correct',
#   'examples': [' "lasted approximately an hour"',
#    ' "in just about a minute"',
#    ' "he\'s about 30 years old"',
#    ' "I\'ve had about all I can stand"',
#    ' "we meet about once a month"',
#    ' "some forty people came"',
#    ' "weighs around a hundred pounds"',
#    ' "roughly $3,000"',
#    ' "holds 3 gallons, more or less"',
#    ' "20 or so people were at the party"  \n']},
#  {'word1': 'approximately',
#   'synonm': ['about', 'some', 'roughly', 'around'],
#   'definition': ' (of quantities) imprecise but fairly close to correct',
#   'examples': [' "lasted approximately an hour"',
#    ' "in just about a minute"',
#    ' "he\'s about 30 years old"',
#    ' "I\'ve had about all I can stand"',
#    ' "we meet about once a month"',
#    ' "some forty people came"',
#    ' "weighs around a hundred pounds"',
#    ' "roughly $3,000"',
#    ' "holds 3 gallons, more or less"',
#    ' "20 or so people were at the party"  \n']},
#  {'word1': 'absolutely',
#   'synonm': [],
#   'definition': ' totally and definitely',
#   'examples': [' without question',
#    ' "we are absolutely opposed to the idea"',
#    ' "he forced himself to lie absolutely still"',
#    ' "iron is absolutely necessary"  \n']},
#  {'word1': 'absolutely',
#   'synonm': [],
#   'definition': ' totally and definitely',
#   'examples': [' without question',
#    ' "we are absolutely opposed to the idea"',
#    ' "he forced himself to lie absolutely still"',
#    ' "iron is absolutely necessary"  \n']},
#  {'word1': 'absolutely',
#   'synonm': [],
#   'definition': ' totally and definitely',
#   'examples': [' without question',
#    ' "we are absolutely opposed to the idea"',
#    ' "he forced himself to lie absolutely still"',
#    ' "iron is absolutely necessary"  \n']},
#  {'word1': 'absolutely',
#   'synonm': [],
#   'definition': ' totally and definitely',
#   'examples': [' without question',
#    ' "we are absolutely opposed to the idea"',
#    ' "he forced himself to lie absolutely still"',
#    ' "iron is absolutely necessary"  \n']},
#  {'word1': 'absolutely',
#   'synonm': [],
#   'definition': ' totally and definitely',
#   'examples': [' without question',
#    ' "we are absolutely opposed to the idea"',
#    ' "he forced himself to lie absolutely still"',
#    ' "iron is absolutely necessary"  \n']},
#  {'word1': 'partially',
#   'synonm': ['partly', 'part'],
#   'definition': ' to some extent',
#   'examples': [' in some degree',
#    ' not wholly',
#    ' "I felt partly to blame"',
#    ' "He was partially paralyzed"  \n']},
#  {'word1': 'partially',
#   'synonm': ['partly', 'part'],
#   'definition': ' to some extent',
#   'examples': [' in some degree',
#    ' not wholly',
#    ' "I felt partly to blame"',
#    ' "He was partially paralyzed"  \n']},
#  {'word1': 'partially',
#   'synonm': ['partly', 'part'],
#   'definition': ' to some extent',
#   'examples': [' in some degree',
#    ' not wholly',
#    ' "I felt partly to blame"',
#    ' "He was partially paralyzed"  \n']},
#  {'word1': 'partially',
#   'synonm': ['partly', 'part'],
#   'definition': ' to some extent',
#   'examples': [' in some degree',
#    ' not wholly',
#    ' "I felt partly to blame"',
#    ' "He was partially paralyzed"  \n']},
#  {'word1': 'partially',
#   'synonm': ['partly', 'part'],
#   'definition': ' to some extent',
#   'examples': [' in some degree',
#    ' not wholly',
#    ' "I felt partly to blame"',
#    ' "He was partially paralyzed"  \n']},
#  {'word1': 'half',
#   'synonm': [],
#   'definition': ' partially or to the extent of a half',
#   'examples': [' "he was half hidden by the bushes"  \n']},
#  {'word1': 'half',
#   'synonm': [],
#   'definition': ' partially or to the extent of a half',
#   'examples': [' "he was half hidden by the bushes"  \n']},
#  {'word1': 'wholly',
#   'synonm': ['entirely',
#    'completely',
#    'totally',
#    'all',
#    'altogether',
#    'whole',
#    'right'],
#   'definition': " to a complete degree or to the full or entire extent (`whole' is often used informally for `wholly')",
#   'examples': [' "he was wholly convinced"',
#    ' "entirely satisfied with the meal"',
#    ' "it was completely different from what we expected"',
#    ' "was completely at fault"',
#    ' "a totally new situation"',
#    ' "the directions were all wrong"',
#    ' "it was not altogether her fault"',
#    ' "an altogether new approach"',
#    ' "a whole new idea"',
#    ' "she felt right at home"',
#    ' "he fell right into the trap"  \n']},
#  {'word1': 'wholly',
#   'synonm': ['entirely',
#    'completely',
#    'totally',
#    'all',
#    'altogether',
#    'whole',
#    'right'],
#   'definition': " to a complete degree or to the full or entire extent (`whole' is often used informally for `wholly')",
#   'examples': [' "he was wholly convinced"',
#    ' "entirely satisfied with the meal"',
#    ' "it was completely different from what we expected"',
#    ' "was completely at fault"',
#    ' "a totally new situation"',
#    ' "the directions were all wrong"',
#    ' "it was not altogether her fault"',
#    ' "an altogether new approach"',
#    ' "a whole new idea"',
#    ' "she felt right at home"',
#    ' "he fell right into the trap"  \n']},
#  {'word1': 'wholly',
#   'synonm': ['entirely',
#    'completely',
#    'totally',
#    'all',
#    'altogether',
#    'whole',
#    'right'],
#   'definition': " to a complete degree or to the full or entire extent (`whole' is often used informally for `wholly')",
#   'examples': [' "he was wholly convinced"',
#    ' "entirely satisfied with the meal"',
#    ' "it was completely different from what we expected"',
#    ' "was completely at fault"',
#    ' "a totally new situation"',
#    ' "the directions were all wrong"',
#    ' "it was not altogether her fault"',
#    ' "an altogether new approach"',
#    ' "a whole new idea"',
#    ' "she felt right at home"',
#    ' "he fell right into the trap"  \n']},
#  {'word1': 'wholly',
#   'synonm': ['entirely',
#    'completely',
#    'totally',
#    'all',
#    'altogether',
#    'whole',
#    'right'],
#   'definition': " to a complete degree or to the full or entire extent (`whole' is often used informally for `wholly')",
#   'examples': [' "he was wholly convinced"',
#    ' "entirely satisfied with the meal"',
#    ' "it was completely different from what we expected"',
#    ' "was completely at fault"',
#    ' "a totally new situation"',
#    ' "the directions were all wrong"',
#    ' "it was not altogether her fault"',
#    ' "an altogether new approach"',
#    ' "a whole new idea"',
#    ' "she felt right at home"',
#    ' "he fell right into the trap"  \n']},
#  {'word1': 'wholly',
#   'synonm': ['entirely',
#    'completely',
#    'totally',
#    'all',
#    'altogether',
#    'whole',
#    'right'],
#   'definition': " to a complete degree or to the full or entire extent (`whole' is often used informally for `wholly')",
#   'examples': [' "he was wholly convinced"',
#    ' "entirely satisfied with the meal"',
#    ' "it was completely different from what we expected"',
#    ' "was completely at fault"',
#    ' "a totally new situation"',
#    ' "the directions were all wrong"',
#    ' "it was not altogether her fault"',
#    ' "an altogether new approach"',
#    ' "a whole new idea"',
#    ' "she felt right at home"',
#    ' "he fell right into the trap"  \n']},
#  {'word1': 'wholly',
#   'synonm': ['entirely',
#    'completely',
#    'totally',
#    'all',
#    'altogether',
#    'whole',
#    'right'],
#   'definition': " to a complete degree or to the full or entire extent (`whole' is often used informally for `wholly')",
#   'examples': [' "he was wholly convinced"',
#    ' "entirely satisfied with the meal"',
#    ' "it was completely different from what we expected"',
#    ' "was completely at fault"',
#    ' "a totally new situation"',
#    ' "the directions were all wrong"',
#    ' "it was not altogether her fault"',
#    ' "an altogether new approach"',
#    ' "a whole new idea"',
#    ' "she felt right at home"',
#    ' "he fell right into the trap"  \n']},
#  {'word1': 'wholly',
#   'synonm': ['entirely',
#    'completely',
#    'totally',
#    'all',
#    'altogether',
#    'whole',
#    'right'],
#   'definition': " to a complete degree or to the full or entire extent (`whole' is often used informally for `wholly')",
#   'examples': [' "he was wholly convinced"',
#    ' "entirely satisfied with the meal"',
#    ' "it was completely different from what we expected"',
#    ' "was completely at fault"',
#    ' "a totally new situation"',
#    ' "the directions were all wrong"',
#    ' "it was not altogether her fault"',
#    ' "an altogether new approach"',
#    ' "a whole new idea"',
#    ' "she felt right at home"',
#    ' "he fell right into the trap"  \n']},
#  {'word1': 'wholly',
#   'synonm': ['entirely',
#    'completely',
#    'totally',
#    'all',
#    'altogether',
#    'whole',
#    'right'],
#   'definition': " to a complete degree or to the full or entire extent (`whole' is often used informally for `wholly')",
#   'examples': [' "he was wholly convinced"',
#    ' "entirely satisfied with the meal"',
#    ' "it was completely different from what we expected"',
#    ' "was completely at fault"',
#    ' "a totally new situation"',
#    ' "the directions were all wrong"',
#    ' "it was not altogether her fault"',
#    ' "an altogether new approach"',
#    ' "a whole new idea"',
#    ' "she felt right at home"',
#    ' "he fell right into the trap"  \n']},
#  {'word1': 'wholly',
#   'synonm': ['entirely',
#    'completely',
#    'totally',
#    'all',
#    'altogether',
#    'whole',
#    'right'],
#   'definition': " to a complete degree or to the full or entire extent (`whole' is often used informally for `wholly')",
#   'examples': [' "he was wholly convinced"',
#    ' "entirely satisfied with the meal"',
#    ' "it was completely different from what we expected"',
#    ' "was completely at fault"',
#    ' "a totally new situation"',
#    ' "the directions were all wrong"',
#    ' "it was not altogether her fault"',
#    ' "an altogether new approach"',
#    ' "a whole new idea"',
#    ' "she felt right at home"',
#    ' "he fell right into the trap"  \n']},
#  {'word1': 'wholly',
#   'synonm': ['entirely',
#    'completely',
#    'totally',
#    'all',
#    'altogether',
#    'whole',
#    'right'],
#   'definition': " to a complete degree or to the full or entire extent (`whole' is often used informally for `wholly')",
#   'examples': [' "he was wholly convinced"',
#    ' "entirely satisfied with the meal"',
#    ' "it was completely different from what we expected"',
#    ' "was completely at fault"',
#    ' "a totally new situation"',
#    ' "the directions were all wrong"',
#    ' "it was not altogether her fault"',
#    ' "an altogether new approach"',
#    ' "a whole new idea"',
#    ' "she felt right at home"',
#    ' "he fell right into the trap"  \n']},
#  {'word1': 'wholly',
#   'synonm': ['entirely',
#    'completely',
#    'totally',
#    'all',
#    'altogether',
#    'whole',
#    'right'],
#   'definition': " to a complete degree or to the full or entire extent (`whole' is often used informally for `wholly')",
#   'examples': [' "he was wholly convinced"',
#    ' "entirely satisfied with the meal"',
#    ' "it was completely different from what we expected"',
#    ' "was completely at fault"',
#    ' "a totally new situation"',
#    ' "the directions were all wrong"',
#    ' "it was not altogether her fault"',
#    ' "an altogether new approach"',
#    ' "a whole new idea"',
#    ' "she felt right at home"',
#    ' "he fell right into the trap"  \n']},
#  {'word1': 'wholly',
#   'synonm': ['entirely',
#    'completely',
#    'totally',
#    'all',
#    'altogether',
#    'whole',
#    'right'],
#   'definition': " to a complete degree or to the full or entire extent (`whole' is often used informally for `wholly')",
#   'examples': [' "he was wholly convinced"',
#    ' "entirely satisfied with the meal"',
#    ' "it was completely different from what we expected"',
#    ' "was completely at fault"',
#    ' "a totally new situation"',
#    ' "the directions were all wrong"',
#    ' "it was not altogether her fault"',
#    ' "an altogether new approach"',
#    ' "a whole new idea"',
#    ' "she felt right at home"',
#    ' "he fell right into the trap"  \n']},
#  {'word1': 'entirely',
#   'synonm': ['exclusively', 'solely', 'alone', 'only'],
#   'definition': ' without any others being included or involved',
#   'examples': [' "was entirely to blame"',
#    ' "a school devoted entirely to the needs of problem children"',
#    ' "he works for Mr. Smith exclusively"',
#    ' "did it solely for money"',
#    ' "the burden of proof rests on the prosecution alone"',
#    ' "a privilege granted only to him"  \n']},
#  {'word1': 'entirely',
#   'synonm': ['exclusively', 'solely', 'alone', 'only'],
#   'definition': ' without any others being included or involved',
#   'examples': [' "was entirely to blame"',
#    ' "a school devoted entirely to the needs of problem children"',
#    ' "he works for Mr. Smith exclusively"',
#    ' "did it solely for money"',
#    ' "the burden of proof rests on the prosecution alone"',
#    ' "a privilege granted only to him"  \n']},
#  {'word1': 'entirely',
#   'synonm': ['exclusively', 'solely', 'alone', 'only'],
#   'definition': ' without any others being included or involved',
#   'examples': [' "was entirely to blame"',
#    ' "a school devoted entirely to the needs of problem children"',
#    ' "he works for Mr. Smith exclusively"',
#    ' "did it solely for money"',
#    ' "the burden of proof rests on the prosecution alone"',
#    ' "a privilege granted only to him"  \n']},
#  {'word1': 'entirely',
#   'synonm': ['exclusively', 'solely', 'alone', 'only'],
#   'definition': ' without any others being included or involved',
#   'examples': [' "was entirely to blame"',
#    ' "a school devoted entirely to the needs of problem children"',
#    ' "he works for Mr. Smith exclusively"',
#    ' "did it solely for money"',
#    ' "the burden of proof rests on the prosecution alone"',
#    ' "a privilege granted only to him"  \n']},
#  {'word1': 'entirely',
#   'synonm': ['exclusively', 'solely', 'alone', 'only'],
#   'definition': ' without any others being included or involved',
#   'examples': [' "was entirely to blame"',
#    ' "a school devoted entirely to the needs of problem children"',
#    ' "he works for Mr. Smith exclusively"',
#    ' "did it solely for money"',
#    ' "the burden of proof rests on the prosecution alone"',
#    ' "a privilege granted only to him"  \n']},
#  {'word1': 'entirely',
#   'synonm': ['exclusively', 'solely', 'alone', 'only'],
#   'definition': ' without any others being included or involved',
#   'examples': [' "was entirely to blame"',
#    ' "a school devoted entirely to the needs of problem children"',
#    ' "he works for Mr. Smith exclusively"',
#    ' "did it solely for money"',
#    ' "the burden of proof rests on the prosecution alone"',
#    ' "a privilege granted only to him"  \n']},
#  {'word1': 'entirely',
#   'synonm': ['exclusively', 'solely', 'alone', 'only'],
#   'definition': ' without any others being included or involved',
#   'examples': [' "was entirely to blame"',
#    ' "a school devoted entirely to the needs of problem children"',
#    ' "he works for Mr. Smith exclusively"',
#    ' "did it solely for money"',
#    ' "the burden of proof rests on the prosecution alone"',
#    ' "a privilege granted only to him"  \n']},
#  {'word1': 'absolutely',
#   'synonm': ['perfectly', 'utterly', 'dead'],
#   'definition': ' completely and without qualification',
#   'examples': [' used informally as intensifiers',
#    ' "an absolutely magnificent painting"',
#    ' "a perfectly idiotic idea"',
#    ' "you\'re perfectly right"',
#    ' "utterly miserable"',
#    ' "you can be dead sure of my innocence"',
#    ' "was dead tired"',
#    ' "dead right"  \n']},
#  {'word1': 'absolutely',
#   'synonm': ['perfectly', 'utterly', 'dead'],
#   'definition': ' completely and without qualification',
#   'examples': [' used informally as intensifiers',
#    ' "an absolutely magnificent painting"',
#    ' "a perfectly idiotic idea"',
#    ' "you\'re perfectly right"',
#    ' "utterly miserable"',
#    ' "you can be dead sure of my innocence"',
#    ' "was dead tired"',
#    ' "dead right"  \n']},
#  {'word1': 'absolutely',
#   'synonm': ['perfectly', 'utterly', 'dead'],
#   'definition': ' completely and without qualification',
#   'examples': [' used informally as intensifiers',
#    ' "an absolutely magnificent painting"',
#    ' "a perfectly idiotic idea"',
#    ' "you\'re perfectly right"',
#    ' "utterly miserable"',
#    ' "you can be dead sure of my innocence"',
#    ' "was dead tired"',
#    ' "dead right"  \n']},
#  {'word1': 'absolutely',
#   'synonm': ['perfectly', 'utterly', 'dead'],
#   'definition': ' completely and without qualification',
#   'examples': [' used informally as intensifiers',
#    ' "an absolutely magnificent painting"',
#    ' "a perfectly idiotic idea"',
#    ' "you\'re perfectly right"',
#    ' "utterly miserable"',
#    ' "you can be dead sure of my innocence"',
#    ' "was dead tired"',
#    ' "dead right"  \n']},
#  {'word1': 'absolutely',
#   'synonm': ['perfectly', 'utterly', 'dead'],
#   'definition': ' completely and without qualification',
#   'examples': [' used informally as intensifiers',
#    ' "an absolutely magnificent painting"',
#    ' "a perfectly idiotic idea"',
#    ' "you\'re perfectly right"',
#    ' "utterly miserable"',
#    ' "you can be dead sure of my innocence"',
#    ' "was dead tired"',
#    ' "dead right"  \n']},
#  {'word1': 'absolutely',
#   'synonm': ['perfectly', 'utterly', 'dead'],
#   'definition': ' completely and without qualification',
#   'examples': [' used informally as intensifiers',
#    ' "an absolutely magnificent painting"',
#    ' "a perfectly idiotic idea"',
#    ' "you\'re perfectly right"',
#    ' "utterly miserable"',
#    ' "you can be dead sure of my innocence"',
#    ' "was dead tired"',
#    ' "dead right"  \n']},
#  {'word1': 'absolutely',
#   'synonm': ['perfectly', 'utterly', 'dead'],
#   'definition': ' completely and without qualification',
#   'examples': [' used informally as intensifiers',
#    ' "an absolutely magnificent painting"',
#    ' "a perfectly idiotic idea"',
#    ' "you\'re perfectly right"',
#    ' "utterly miserable"',
#    ' "you can be dead sure of my innocence"',
#    ' "was dead tired"',
#    ' "dead right"  \n']},
#  {'word1': 'absolutely',
#   'synonm': ['perfectly', 'utterly', 'dead'],
#   'definition': ' completely and without qualification',
#   'examples': [' used informally as intensifiers',
#    ' "an absolutely magnificent painting"',
#    ' "a perfectly idiotic idea"',
#    ' "you\'re perfectly right"',
#    ' "utterly miserable"',
#    ' "you can be dead sure of my innocence"',
#    ' "was dead tired"',
#    ' "dead right"  \n']},
#  {'word1': 'absolutely',
#   'synonm': ['perfectly', 'utterly', 'dead'],
#   'definition': ' completely and without qualification',
#   'examples': [' used informally as intensifiers',
#    ' "an absolutely magnificent painting"',
#    ' "a perfectly idiotic idea"',
#    ' "you\'re perfectly right"',
#    ' "utterly miserable"',
#    ' "you can be dead sure of my innocence"',
#    ' "was dead tired"',
#    ' "dead right"  \n']},
#  {'word1': 'clean',
#   'synonm': ['plumb', 'plum'],
#   'definition': ' completely',
#   'examples': [' used as intensifiers',
#    ' "clean forgot the appointment"',
#    ' "I\'m plumb (or plum) tuckered out"  \n']},
#  {'word1': 'clean',
#   'synonm': ['plumb', 'plum'],
#   'definition': ' completely',
#   'examples': [' used as intensifiers',
#    ' "clean forgot the appointment"',
#    ' "I\'m plumb (or plum) tuckered out"  \n']},
#  {'word1': 'clean',
#   'synonm': ['plumb', 'plum'],
#   'definition': ' completely',
#   'examples': [' used as intensifiers',
#    ' "clean forgot the appointment"',
#    ' "I\'m plumb (or plum) tuckered out"  \n']},
#  {'word1': 'clean',
#   'synonm': ['plumb', 'plum'],
#   'definition': ' completely',
#   'examples': [' used as intensifiers',
#    ' "clean forgot the appointment"',
#    ' "I\'m plumb (or plum) tuckered out"  \n']},
#  {'word1': 'plumb',
#   'synonm': ['plum'],
#   'definition': ' exactly',
#   'examples': [' "fell plumb in the middle of the puddle"  \n']},
#  {'word1': 'plumb',
#   'synonm': ['plum'],
#   'definition': ' exactly',
#   'examples': [' "fell plumb in the middle of the puddle"  \n']},
#  {'word1': 'perfectly',
#   'synonm': [],
#   'definition': ' in a perfect or faultless way',
#   'examples': [' "She performed perfectly on the balance beam"',
#    ' "spoke English perfectly"',
#    ' "solved the problem perfectly"  \n']},
#  {'word1': 'perfectly',
#   'synonm': [],
#   'definition': ' in a perfect or faultless way',
#   'examples': [' "She performed perfectly on the balance beam"',
#    ' "spoke English perfectly"',
#    ' "solved the problem perfectly"  \n']},
#  {'word1': 'perfectly',
#   'synonm': [],
#   'definition': ' in a perfect or faultless way',
#   'examples': [' "She performed perfectly on the balance beam"',
#    ' "spoke English perfectly"',
#    ' "solved the problem perfectly"  \n']},
#  {'word1': 'perfectly',
#   'synonm': [],
#   'definition': ' in a perfect or faultless way',
#   'examples': [' "She performed perfectly on the balance beam"',
#    ' "spoke English perfectly"',
#    ' "solved the problem perfectly"  \n']},
#  {'word1': 'pat',
#   'synonm': [],
#   'definition': ' completely or perfectly',
#   'examples': [' "he has the lesson pat"', ' "had the system down pat"  \n']},
#  {'word1': 'pat',
#   'synonm': [],
#   'definition': ' completely or perfectly',
#   'examples': [' "he has the lesson pat"', ' "had the system down pat"  \n']},
#  {'word1': 'pat',
#   'synonm': [],
#   'definition': ' completely or perfectly',
#   'examples': [' "he has the lesson pat"', ' "had the system down pat"  \n']},
#  {'word1': 'please',
#   'synonm': [],
# ...
#   'examples': [' "Now the next problem is..."  \n']},
#  {'word1': 'now',
#   'synonm': [],
#   'definition': ' (prefatory or transitional) indicates a change of subject or activity',
#   'examples': [' "Now the next problem is..."  \n']},
#  {'word1': 'now',
#   'synonm': [],
#   'definition': ' interjection of rebuke  \n',
#   'examples': []},
#  {'word1': 'aggressively',
#   'synonm': ['sharply'],
#   'definition': ' in an aggressive manner',
#   'examples': [' "she was being sharply questioned"  \n']},
#  {'word1': 'aggressively',
#   'synonm': ['sharply'],
#   'definition': ' in an aggressive manner',
#   'examples': [' "she was being sharply questioned"  \n']},
#  {'word1': 'shrilly',
#   'synonm': ['piercingly'],
#   'definition': ' in a shrill voice',
#   'examples': [' "she sang rather shrilly"  \n']},
#  {'word1': 'shrilly',
#   'synonm': ['piercingly'],
#   'definition': ' in a shrill voice',
#   'examples': [' "she sang rather shrilly"  \n']},
#  {'word1': 'steadily',
#   'synonm': [],
#   'definition': ' at a steady rate or pace',
#   'examples': [' "his interest eroded steadily"  \n']},
#  {'word1': 'steadily',
#   'synonm': [],
#   'definition': ' at a steady rate or pace',
#   'examples': [' "his interest eroded steadily"  \n']},
#  {'word1': 'happily',
#   'synonm': ['merrily', 'mirthfully', 'gayly', 'blithely', 'jubilantly'],
#   'definition': ' in a joyous manner',
#   'examples': [' "they shouted happily"  \n']},
#  {'word1': 'happily',
#   'synonm': ['merrily', 'mirthfully', 'gayly', 'blithely', 'jubilantly'],
#   'definition': ' in a joyous manner',
#   'examples': [' "they shouted happily"  \n']},
#  {'word1': 'unhappily',
#   'synonm': [],
#   'definition': ' in an unpleasant way',
#   'examples': [' "they were unhappily married"  \n']},
#  {'word1': 'unhappily',
#   'synonm': [],
#   'definition': ' in an unpleasant way',
#   'examples': [' "they were unhappily married"  \n']},
#  {'word1': 'no',
#   'synonm': [],
#   'definition': ' referring to the degree to which a certain quality is present',
#   'examples': [' "he was no heavier than a child"  \n']},
#  {'word1': 'no',
#   'synonm': [],
#   'definition': ' referring to the degree to which a certain quality is present',
#   'examples': [' "he was no heavier than a child"  \n']},
#  {'word1': 'firm',
#   'synonm': ['firmly', 'steadfastly', 'unwaveringly'],
#   'definition': ' with resolute determination',
#   'examples': [' "we firmly believed it"', ' "you must stand firm"  \n']},
#  {'word1': 'firm',
#   'synonm': ['firmly', 'steadfastly', 'unwaveringly'],
#   'definition': ' with resolute determination',
#   'examples': [' "we firmly believed it"', ' "you must stand firm"  \n']},
#  {'word1': 'firm',
#   'synonm': ['firmly', 'steadfastly', 'unwaveringly'],
#   'definition': ' with resolute determination',
#   'examples': [' "we firmly believed it"', ' "you must stand firm"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['foursquare', 'straightforwardly'],
#   'definition': ' with firmness and conviction',
#   'examples': [' without compromise',
#    ' "he stood foursquare for religious liberty and toleration"- C.G.Bowers',
#    ' "dealt straightforwardly with all issues"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['foursquare', 'straightforwardly'],
#   'definition': ' with firmness and conviction',
#   'examples': [' without compromise',
#    ' "he stood foursquare for religious liberty and toleration"- C.G.Bowers',
#    ' "dealt straightforwardly with all issues"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['foursquare', 'straightforwardly'],
#   'definition': ' with firmness and conviction',
#   'examples': [' without compromise',
#    ' "he stood foursquare for religious liberty and toleration"- C.G.Bowers',
#    ' "dealt straightforwardly with all issues"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['foursquare', 'straightforwardly'],
#   'definition': ' with firmness and conviction',
#   'examples': [' without compromise',
#    ' "he stood foursquare for religious liberty and toleration"- C.G.Bowers',
#    ' "dealt straightforwardly with all issues"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['square'],
#   'definition': ' firmly and solidly',
#   'examples': [' "hit the ball squarely"',
#    ' "the bat met the ball squarely"',
#    ' "planted his great bulk square before his enemy"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['square'],
#   'definition': ' firmly and solidly',
#   'examples': [' "hit the ball squarely"',
#    ' "the bat met the ball squarely"',
#    ' "planted his great bulk square before his enemy"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['square'],
#   'definition': ' firmly and solidly',
#   'examples': [' "hit the ball squarely"',
#    ' "the bat met the ball squarely"',
#    ' "planted his great bulk square before his enemy"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['square'],
#   'definition': ' firmly and solidly',
#   'examples': [' "hit the ball squarely"',
#    ' "the bat met the ball squarely"',
#    ' "planted his great bulk square before his enemy"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['square'],
#   'definition': ' in a square shape',
#   'examples': [' "a squarely cut piece of paper"',
#    ' "folded the sheet of paper square"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['square'],
#   'definition': ' in a square shape',
#   'examples': [' "a squarely cut piece of paper"',
#    ' "folded the sheet of paper square"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['square'],
#   'definition': ' in a square shape',
#   'examples': [' "a squarely cut piece of paper"',
#    ' "folded the sheet of paper square"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['forthrightly', 'forthright'],
#   'definition': ' directly and without evasion',
#   'examples': [' not roundabout',
#    ' "to face a problem squarely"',
#    ' "the responsibility lies squarely with them"',
#    ' "spoke forthright (or forthrightly) and to the point"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['forthrightly', 'forthright'],
#   'definition': ' directly and without evasion',
#   'examples': [' not roundabout',
#    ' "to face a problem squarely"',
#    ' "the responsibility lies squarely with them"',
#    ' "spoke forthright (or forthrightly) and to the point"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['forthrightly', 'forthright'],
#   'definition': ' directly and without evasion',
#   'examples': [' not roundabout',
#    ' "to face a problem squarely"',
#    ' "the responsibility lies squarely with them"',
#    ' "spoke forthright (or forthrightly) and to the point"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['forthrightly', 'forthright'],
#   'definition': ' directly and without evasion',
#   'examples': [' not roundabout',
#    ' "to face a problem squarely"',
#    ' "the responsibility lies squarely with them"',
#    ' "spoke forthright (or forthrightly) and to the point"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['forthrightly', 'forthright'],
#   'definition': ' directly and without evasion',
#   'examples': [' not roundabout',
#    ' "to face a problem squarely"',
#    ' "the responsibility lies squarely with them"',
#    ' "spoke forthright (or forthrightly) and to the point"  \n']},
#  {'word1': 'directly',
#   'synonm': ['straight', 'direct'],
#   'definition': ' without deviation',
#   'examples': [' "the path leads directly to the lake"',
#    ' "went direct to the office"  \n']},
#  {'word1': 'directly',
#   'synonm': ['straight', 'direct'],
#   'definition': ' without deviation',
#   'examples': [' "the path leads directly to the lake"',
#    ' "went direct to the office"  \n']},
#  {'word1': 'directly',
#   'synonm': ['straight', 'direct'],
#   'definition': ' without deviation',
#   'examples': [' "the path leads directly to the lake"',
#    ' "went direct to the office"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['square'],
#   'definition': ' in a straight direct way',
#   'examples': [' "looked him squarely in the eye"',
#    ' "ran square into me"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['square'],
#   'definition': ' in a straight direct way',
#   'examples': [' "looked him squarely in the eye"',
#    ' "ran square into me"  \n']},
#  {'word1': 'squarely',
#   'synonm': ['square'],
#   'definition': ' in a straight direct way',
#   'examples': [' "looked him squarely in the eye"',
#    ' "ran square into me"  \n']},
#  {'word1': 'due',
#   'synonm': [],
#   'definition': ' directly or exactly',
#   'examples': [' straight', ' "went due North"  \n']},
#  {'word1': 'due',
#   'synonm': [],
#   'definition': ' directly or exactly',
#   'examples': [' straight', ' "went due North"  \n']},
#  {'word1': 'due',
#   'synonm': [],
#   'definition': ' directly or exactly',
#   'examples': [' straight', ' "went due North"  \n']},
#  {'word1': 'variously',
#   'synonm': ['diversely', 'multifariously'],
#   'definition': ' in diverse ways',
#   'examples': [' "the alternatives that are variously represented by the participants"',
#    ' "the speakers treated the subject most diversely"  \n']},
#  {'word1': 'variously',
#   'synonm': ['diversely', 'multifariously'],
#   'definition': ' in diverse ways',
#   'examples': [' "the alternatives that are variously represented by the participants"',
#    ' "the speakers treated the subject most diversely"  \n']},
#  {'word1': 'variously',
#   'synonm': ['diversely', 'multifariously'],
#   'definition': ' in diverse ways',
#   'examples': [' "the alternatives that are variously represented by the participants"',
#    ' "the speakers treated the subject most diversely"  \n']},
#  {'word1': 'indefatigably',
#   'synonm': ['tirelessly', 'inexhaustibly'],
#   'definition': ' with indefatigable energy',
#   'examples': [' "she watched the show indefatigably"  \n']},
#  {'word1': 'indefatigably',
#   'synonm': ['tirelessly', 'inexhaustibly'],
#   'definition': ' with indefatigable energy',
#   'examples': [' "she watched the show indefatigably"  \n']},
#  {'word1': 'biradially',
#   'synonm': [],
#   'definition': ' in a biradial manner',
#   'examples': [' "biradially symmetrical"  \n']},
#  {'word1': 'biradially',
#   'synonm': [],
#   'definition': ' in a biradial manner',
#   'examples': [' "biradially symmetrical"  \n']},
#  {'word1': 'bitterly',
#   'synonm': [],
#   'definition': ' with bitterness',
#   'examples': [' in a resentful manner', ' "she complained bitterly"  \n']},
#  {'word1': 'bitterly',
#   'synonm': [],
#   'definition': ' with bitterness',
#   'examples': [' in a resentful manner', ' "she complained bitterly"  \n']},
#  {'word1': 'bitterly',
#   'synonm': [],
#   'definition': ' with bitterness',
#   'examples': [' in a resentful manner', ' "she complained bitterly"  \n']},
#  {'word1': 'bitterly',
#   'synonm': [],
#   'definition': ' indicating something hard to accept',
#   'examples': [' "he was bitterly disappointed"  \n']},
#  {'word1': 'bitterly',
#   'synonm': [],
#   'definition': ' indicating something hard to accept',
#   'examples': [' "he was bitterly disappointed"  \n']},
#  {'word1': 'fine',
#   'synonm': ['alright', 'OK'],
#   'definition': ' an expression of agreement normally occurring at the beginning of a sentence  \n',
#   'examples': []},
#  {'word1': 'alright',
#   'synonm': [],
#   'definition': ' without doubt (used to reinforce an assertion)',
#   'examples': [' "it\'s expensive all right"  \n']},
#  {'word1': 'alright',
#   'synonm': [],
#   'definition': ' without doubt (used to reinforce an assertion)',
#   'examples': [' "it\'s expensive all right"  \n']},
#  {'word1': 'swiftly',
#   'synonm': ['fleetly'],
#   'definition': ' in a swift manner',
#   'examples': [' "she moved swiftly"  \n']},
#  {'word1': 'swiftly',
#   'synonm': ['fleetly'],
#   'definition': ' in a swift manner',
#   'examples': [' "she moved swiftly"  \n']},
#  {'word1': 'openly',
#   'synonm': [],
#   'definition': ' in an open way',
#   'examples': [' "he openly flaunted his affection for his sister"  \n']},
#  {'word1': 'openly',
#   'synonm': [],
#   'definition': ' in an open way',
#   'examples': [' "he openly flaunted his affection for his sister"  \n']},
#  {'word1': 'practically',
#   'synonm': [],
#   'definition': ' in a practical manner',
#   'examples': [' "practically orientated institutions such as business schools"',
#    ' "a brilliant man but so practically inept that he needed help to cross the road safely"  \n']},
#  {'word1': 'practically',
#   'synonm': [],
#   'definition': ' in a practical manner',
#   'examples': [' "practically orientated institutions such as business schools"',
#    ' "a brilliant man but so practically inept that he needed help to cross the road safely"  \n']},
#  {'word1': 'practically',
#   'synonm': [],
#   'definition': ' in a practical manner',
#   'examples': [' "practically orientated institutions such as business schools"',
#    ' "a brilliant man but so practically inept that he needed help to cross the road safely"  \n']},
#  {'word1': 'practically',
#   'synonm': [],
#   'definition': ' almost',
#   'examples': [' nearly',
#    ' "practically the first thing I saw when I got off the train"',
#    ' "he was practically the only guest at the party"',
#    ' "there was practically no garden at all"  \n']},
#  {'word1': 'practically',
#   'synonm': [],
#   'definition': ' almost',
#   'examples': [' nearly',
#    ' "practically the first thing I saw when I got off the train"',
#    ' "he was practically the only guest at the party"',
#    ' "there was practically no garden at all"  \n']},
#  {'word1': 'practically',
#   'synonm': [],
#   'definition': ' almost',
#   'examples': [' nearly',
#    ' "practically the first thing I saw when I got off the train"',
#    ' "he was practically the only guest at the party"',
#    ' "there was practically no garden at all"  \n']},
#  {'word1': 'practically',
#   'synonm': [],
#   'definition': ' almost',
#   'examples': [' nearly',
#    ' "practically the first thing I saw when I got off the train"',
#    ' "he was practically the only guest at the party"',
#    ' "there was practically no garden at all"  \n']},
#  {'word1': 'practically',
#   'synonm': [],
#   'definition': ' almost',
#   'examples': [' nearly',
#    ' "practically the first thing I saw when I got off the train"',
#    ' "he was practically the only guest at the party"',
#    ' "there was practically no garden at all"  \n']},
#  {'word1': 'presumably',
#   'synonm': ['presumptively'],
#   'definition': ' by reasonable assumption',
#   'examples': [' "presumably, he missed the train"  \n']},
#  {'word1': 'presumably',
#   'synonm': ['presumptively'],
#   'definition': ' by reasonable assumption',
#   'examples': [' "presumably, he missed the train"  \n']},
#  {'word1': 'pyramidically',
#   'synonm': [],
#   'definition': ' in a pyramidal manner or shape',
#   'examples': [' "the bush was trimmed pyramidically"  \n']},
#  {'word1': 'pyramidically',
#   'synonm': [],
#   'definition': ' in a pyramidal manner or shape',
#   'examples': [' "the bush was trimmed pyramidically"  \n']},
#  {'word1': 'next',
#   'synonm': [],
#   'definition': ' at the time or occasion immediately following',
#   'examples': [' "next the doctor examined his back"  \n']},
#  {'word1': 'next',
#   'synonm': [],
#   'definition': ' at the time or occasion immediately following',
#   'examples': [' "next the doctor examined his back"  \n']},
#  {'word1': 'next',
#   'synonm': [],
#   'definition': ' temporarily',
#   'examples': [' "we\'ll stop for the time being"  \n']},
#  {'word1': 'next',
#   'synonm': [],
#   'definition': ' temporarily',
#   'examples': [' "we\'ll stop for the time being"  \n']},
#  {'word1': 'easily',
#   'synonm': [],
#   'definition': ' without question',
#   'examples': [' "easily the best book she\'s written"  \n']},
#  {'word1': 'easily',
#   'synonm': [],
#   'definition': ' without question',
#   'examples': [' "easily the best book she\'s written"  \n']},
#  {'word1': 'easily',
#   'synonm': [],
#   'definition': ' without the use of a machine',
#   'examples': [' "this dress is sewn by hand"  \n']},
#  {'word1': 'easily',
#   'synonm': [],
#   'definition': ' without the use of a machine',
#   'examples': [' "this dress is sewn by hand"  \n']},
#  {'word1': 'easily',
#   'synonm': [],
#   'definition': ' with the use of a machine',
#   'examples': [' "the shirt is sewn by machine"  \n']},
#  {'word1': 'easily',
#   'synonm': [],
#   'definition': ' with the use of a machine',
#   'examples': [' "the shirt is sewn by machine"  \n']},
#  {'word1': 'easily',
#   'synonm': [],
#   'definition': ' at close quarters',
#   'examples': [' "fought hand to hand"  \n']},
#  ...]
